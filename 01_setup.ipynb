# %%
schema_name = "insurance_lakehouse"

spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema_name}")
spark.sql(f"USE {schema_name}")

print(f"Schema ready: {schema_name}")
# Out:
# Schema ready: insurance_lakehouse
